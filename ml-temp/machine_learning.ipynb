# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
sns.set()
# Out:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
data = pd.read_excel('abc.xlsx')
data
# Out:
#      country  Rating  number_of_customers  Experience In Years  \
# 0        USA    3.75                   53                    6
# 1        UKG    2.75                   37                    1
# 2        NTH    3.00                   57                    6
# 3        FRN    3.50                   47                    3
# 4        SWZ    3.50                   85                    1
# ...      ...     ...                  ...                  ...
# 1995     BRA     NaN                   38                    2
# 1996     BOL     NaN                   97                    6
# 1997     CHL     NaN                   18                    6
# 1998     ARG     NaN                   18                    7
# 1999     NaN     NaN                   20                    4
#
#       number_of_reviews  type_of_consultant     fname     lname        LAT  \
# 0                    53                 NaN      Emma     SMITH  40.106226
# ...

# %%
import random
types_of_consultant = ['Career','Lawyer','Doctor','Education']
ls = []
# for i in range(2000):
#     x = random.randint(0,4)
#     print(x)
#     ls.append(types_of_consultant[x])
# ls
data['type_of_consultant'] = [types_of_consultant[random.randint(0,3)] for i in range(2000)]
data.to_csv('final.csv')
