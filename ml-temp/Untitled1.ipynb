# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
import joblib
sns.set()
# Out:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
data = pd.read_csv('database_data.csv')
data = data.drop('Unnamed: 0', axis = 1)
data = data.set_index('id')
data
# Out:
#       user_id    phone_no country  ratings  number_of_reviews  \
# id
# 2           3  9687014144      IN     0.00                  0
# 1           2  9687014144      IN     0.00                  0
# 3           4  9687014144      IN     0.00                  0
# 4           8  9999999999      IN     0.00                  0
# 5           9  9999999999      IN     0.00                  0
# ...       ...         ...     ...      ...                ...
# 2002        2  9999999999     BRA     3.00                 38
# 2003        2  9999999999     BOL     3.00                 97
# 2004        2  9999999999     CHL     3.00                 18
# 2005        2  9999999999     ARG     3.50                 18
# 2006        2  9999999999     BOL     3.25                 20
#
#       number_of_customers  years_of_experience type_of_consultant  \
# id
# 2                       0                    1             Career
# 1                       0                    1             Career
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
encoder = OrdinalEncoder()
encoder.fit([['Career'],['Doctor'],['Education'],['Lawyer']])
joblib.dump(encoder,'LabelEncoder.sav')
# Out:
# ['LabelEncoder.sav']

# %%
xy = encoder.transform(data.iloc[4:5,:]['type_of_consultant'].values.reshape(-1,1))
print(xy)
he = OneHotEncoder()
ab = he.fit_transform(xy).toarray()
ab
# Out:
# [[3.]]
# array([[1.]])
