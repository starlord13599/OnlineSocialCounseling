# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.NOIJJG62EMASZI6NYURL6JBKM4EVBGM7.gfortran-win_amd64.dll
# C:\Users\Jay\AppData\Roaming\Python\Python36\site-packages\numpy\.libs\libopenblas.QVLO2T66WEPI7JZ63PS3HMOHFEY472BC.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
data = pd.read_csv('jay_data.csv')

# %%
data
# Out:
#       Unnamed: 0        LAT       LONG
# 0              0  40.106226 -18.907997
# 1              1  40.792695  40.369819
# 2              2  15.659023  -9.043448
# 3              3   7.585640 -17.059711
# 4              4  -5.830023  -6.814701
# ...          ...        ...        ...
# 1995        1995  28.401277 -20.917247
# 1996        1996 -10.951971   9.726965
# 1997        1997  -3.139112 -25.493522
# 1998        1998 -30.500899  -2.314013
# 1999        1999 -11.565674 -30.016079
#
# [2000 rows x 3 columns]

# %%
plt.scatter(data['LAT'],data['LONG'])
plt.xlabel('LATITUDE')
plt.ylabel("LONGITUDE")
plt.show()
